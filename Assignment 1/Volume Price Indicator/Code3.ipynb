# %%
####### Here I have calculated the Volume Price Indicator ###########

import numpy as np
import pandas as pd
import yfinance as yf
import math
import matplotlib.pyplot as plt

# %%
data = yf.download("AAPL", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# data['Close'].pct_change(): This calculates the percentage change in the closing price from one period to the next. The pct_change() function computes the difference between the current closing price and the previous closing price, divided by the previous closing price.

# %%
data['Price Change'] = data['Close'].pct_change()
data['Price Change'].fillna(0, inplace=True)

# %% [markdown]
# Volume Price Trend Calculation:
#
# Multiply the volume by the percentage price change to get the volume-adjusted price change for each period.
# Compute the cumulative sum of these volume-adjusted price changes to get the VPT.

# %%
# Calculate Volume Price Trend
data['VPT'] = (data['Volume'] * data['Price Change']).cumsum()
data
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2017-01-03  28.950001  29.082500  28.690001  29.037500  26.952711  115127600
# 2017-01-04  28.962500  29.127501  28.937500  29.004999  26.922543   84472400
# 2017-01-05  28.980000  29.215000  28.952499  29.152500  27.059456   88774400
# 2017-01-06  29.195000  29.540001  29.117500  29.477501  27.361122  127007600
# 2017-01-09  29.487499  29.857500  29.485001  29.747499  27.611732  134247600
# ...               ...        ...        ...        ...        ...        ...
# 2017-04-24  35.875000  35.987499  35.794998  35.910000  33.476303   68537200
# 2017-04-25  35.977501  36.224998  35.967499  36.132500  33.683720   75486000
# 2017-04-26  36.117500  36.150002  35.845001  35.919998  33.485622   80164800
# 2017-04-27  35.980000  36.040001  35.827499  35.947498  33.511253   56985200
# 2017-04-28  36.022499  36.075001  35.817501  35.912498  33.478626   83441600
#
# ...
